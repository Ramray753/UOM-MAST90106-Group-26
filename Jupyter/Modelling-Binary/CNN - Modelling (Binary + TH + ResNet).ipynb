# %% [markdown]
# # CNN - Modelling (Binary + TH + ResNet)
#
# # 1. Construct `ImageDataGenerator` Instance

# %%
import tensorflow as tf
# %matplotlib inline

print(tf.__version__)
# Out:
# 2.4.2

# %%
! nvidia-smi
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Thu Aug 12 10:39:14 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.142.00   Driver Version: 450.142.00   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   42C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# We center and standardize all images at per image level.
#
# Image flips, 180 degree image rotations and image brightness is suitable for data augmentation. However, shift and zoom are not appropriate because some crackes are located at the edge of some images. Zoom and shift may remove those crackes.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen_train = ImageDataGenerator(horizontal_flip=True,
                                    vertical_flip=True,
                                    samplewise_center=True,
                                    samplewise_std_normalization=True)

datagen_test = ImageDataGenerator(samplewise_center=True,
                                   samplewise_std_normalization=True)

# %% [markdown]
# Then, load the data from directory:

# %%
from crack_utils import load_binary_dataset

SRC_BINARY = "/home/ubuntu/crack/TH-Binary/"

x_train, x_test, y_train, y_test = load_binary_dataset(SRC_BINARY, (150, 150))

train_it = datagen_train.flow(x_train, y_train, batch_size=64, seed=100)
test_it = datagen_test.flow(x_test, y_test, batch_size=64, seed=100)

# %% [markdown]
# # 2. Residual Model
#
# ## 2.1 Baseline Model
#
# We consider Residual Module in our baseline model.
#
# ### 2.2.2 One Block Residual Model

# %%
from crack_utils import residual_module, classification_block, feature_reduce_block, binary_compile
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, MaxPooling2D

def one_block_Residual():
    # define model input
    visible = Input(shape=(150, 150, 1))
    # add residual module
    layer = residual_module(visible, 32)
    # add pooling layer
    layer = MaxPooling2D((3, 3))(layer)
    # add classification block
    layer = classification_block(layer, 16)
    # create model
    model = Model(inputs=visible, outputs=layer)
    return model

# create model instance
model = one_block_Residual()
binary_compile(model, 0.001, 0.9)
model.summary()
# Out:
# Extension horovod.torch has not been built: /home/ubuntu/anaconda3/envs/tensorflow2_latest_p37/lib/python3.7/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-37m-x86_64-linux-gnu.so not found
# If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# Warning! MPI libs are missing, but python applications are still avaiable.
# [2021-08-12 10:39:50.532 ip-172-31-5-51:9807 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-08-12 10:39:50.594 ip-172-31-5-51:9807 INFO profiler_config_parser.py:102] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 150, 150, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 150, 150, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 150, 150, 32) 64          input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 150, 32) 0           conv2d_2[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 150, 150, 32) 0           add[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 50, 50, 32)   0           activation[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 80000)        0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           1280016     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            17          dense[0][0]
# ==================================================================================================
# Total params: 1,289,665
# Trainable params: 1,289,665
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

# plot model architecture
plot_model(model, show_shapes=True, to_file='model_image/Bi_TH_Residual_1.png')

# %%
# %%time

histories = dict()

histories["Bi_TH_Residual_1"] = model.fit(train_it, steps_per_epoch=len(train_it),
              validation_data=test_it, validation_steps=len(test_it), epochs=30, verbose=0).history
# Out:
# CPU times: user 1min 58s, sys: 8 s, total: 2min 6s
# Wall time: 3min 15s

# %%
from crack_utils import summarize_diagnostics_binary
                                           
summarize_diagnostics_binary(histories["Bi_TH_Residual_1"], "model_plot/Bi_TH_Residual_1.png")

# %%
from crack_utils import show_result

show_result(model, test_it)
# Out:
# Test loss: 0.69
# Test Accuracy: 0.50
# Test Precision: 0.00
# Test True Positive Rate: 0.00

# %% [markdown]
# ### 2.1.2 Two Block Residual Model

# %%
def two_block_Residual():
    # define model input
    visible = Input(shape=(150, 150, 1))
    # add residual module
    layer = residual_module(visible, 32)
    # add pooling layer
    layer = MaxPooling2D((3, 3))(layer)
    # add pooling layer
    layer = residual_module(layer, 64)
    # add pooling layer
    layer = MaxPooling2D((3, 3))(layer)
    # add classification block
    layer = classification_block(layer, 16)
    # create model
    model = Model(inputs=visible, outputs=layer)
    return model

# create model instance
model = two_block_Residual()
binary_compile(model, 0.001, 0.9)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 150, 150, 32) 9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 150, 150, 32) 64          input_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 150, 32) 0           conv2d_5[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 32) 0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 50, 50, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 50, 50, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 50, 50, 64)   2112        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 50, 50, 64)   0           conv2d_8[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 50, 50, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 16384)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           262160      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            17          dense_2[0][0]
# ==================================================================================================
# Total params: 329,345
# Trainable params: 329,345
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# plot model architecture
plot_model(model, show_shapes=True, to_file='model_image/Bi_TH_Residual_2.png')

# %%
# %%time

histories["Bi_TH_Residual_2"] = model.fit(train_it, steps_per_epoch=len(train_it),
              validation_data=test_it, validation_steps=len(test_it), epochs=30, verbose=0).history
# Out:
# CPU times: user 2min 12s, sys: 10 s, total: 2min 23s
# Wall time: 3min 54s

# %%
summarize_diagnostics_binary(histories["Bi_TH_Residual_2"], "model_plot/Bi_TH_Residual_2.png")

# %%
show_result(model, test_it)
# Out:
# Test loss: 0.69
# Test Accuracy: 0.50
# Test Precision: 0.50
# Test True Positive Rate: 1.00

# %% [markdown]
# ## 2.2 Model Improvements
#
# ### 2.2.1 Dropout Regularization

# %%
from tensorflow.keras.layers import Dropout

def two_block_Residual_dropout():
    # define model input
    visible = Input(shape=(150, 150, 1))
    # add residual module
    layer = residual_module(visible, 32)
    # add pooling layer
    layer = MaxPooling2D((3, 3))(layer)
    layer = Dropout(0.3)(layer)
    # add pooling layer
    layer = residual_module(layer, 64)
    # add pooling layer
    layer = MaxPooling2D((3, 3))(layer)
    layer = Dropout(0.4)(layer)
    # add classification block
    layer = classification_block(layer, 16)
    # create model
    model = Model(inputs=visible, outputs=layer)
    return model

# create model instance
model = two_block_Residual_dropout()
binary_compile(model, 0.001, 0.9)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 150, 150, 32) 320         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 150, 150, 32) 9248        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 150, 150, 32) 64          input_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 150, 32) 0           conv2d_11[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 150, 150, 32) 0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 50, 50, 32)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 50, 50, 32)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 50, 50, 64)   18496       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 50, 50, 64)   36928       conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 50, 50, 64)   2112        dropout[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 50, 64)   0           conv2d_14[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 50, 50, 64)   0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 64)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 64)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 16384)        0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           262160      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            17          dense_4[0][0]
# ==================================================================================================
# Total params: 329,345
# Trainable params: 329,345
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# plot model architecture
plot_model(model, show_shapes=True, to_file='model_image/Bi_TH_Residual_2_dropout.png')

# %%
# %%time

histories["Bi_TH_Residual_2_dropout"] = model.fit(train_it, steps_per_epoch=len(train_it), 
                    validation_data=test_it, validation_steps=len(test_it), epochs=30, verbose=0).history
# Out:
# CPU times: user 2min 10s, sys: 9.27 s, total: 2min 19s
# Wall time: 3min 57s

# %%
summarize_diagnostics_binary(histories["Bi_TH_Residual_2_dropout"], "model_plot/Bi_TH_Residual_2_dropout.png")

# %%
show_result(model, test_it)
# Out:
# Test loss: 0.69
# Test Accuracy: 0.50
# Test Precision: 0.50
# Test True Positive Rate: 1.00

# %% [markdown]
# ### 2.2.1 Weight Decay + Dropout

# %%
from tensorflow.keras.regularizers import l2

def two_block_Residual_dropout_decay():
    # define model input
    visible = Input(shape=(150, 150, 1))
    # add residual module
    layer = residual_module(visible, 32, decay=l2(0.01))
    # add pooling layer
    layer = MaxPooling2D((3, 3))(layer)
    layer = Dropout(0.3)(layer)
    # add pooling layer
    layer = residual_module(layer, 64, decay=l2(0.01))
    # add pooling layer
    layer = MaxPooling2D((3, 3))(layer)
    layer = Dropout(0.4)(layer)
    # add classification block
    layer = classification_block(layer, 16, decay=l2(0.01))
    # create model
    model = Model(inputs=visible, outputs=layer)
    return model

# create model instance
model = two_block_Residual_dropout_decay()
binary_compile(model, 0.001, 0.9)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 150, 150, 32) 320         input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 150, 150, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 150, 150, 32) 64          input_4[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 150, 32) 0           conv2d_17[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 150, 150, 32) 0           add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 50, 50, 32)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 50, 50, 32)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 50, 50, 64)   18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 50, 50, 64)   36928       conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 50, 50, 64)   2112        dropout_2[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 50, 50, 64)   0           conv2d_20[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50, 50, 64)   0           add_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 64)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 16384)        0           dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 16)           262160      flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            17          dense_6[0][0]
# ==================================================================================================
# Total params: 329,345
# Trainable params: 329,345
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# plot model architecture
plot_model(model, show_shapes=True, to_file='model_image/Bi_TH_Residual_2_dropout_decay.png')

# %%
# %%time

histories["Bi_TH_Residual_2_dropout_decay"] = model.fit(train_it, steps_per_epoch=len(train_it), 
                          validation_data=test_it, validation_steps=len(test_it), epochs=30, verbose=0).history
# Out:
# CPU times: user 2min 22s, sys: 11.3 s, total: 2min 34s
# Wall time: 3min 58s

# %%
summarize_diagnostics_binary(histories["Bi_TH_Residual_2_dropout_decay"], "model_plot/Bi_TH_Residual_2_dropout_decay.png")

# %%
show_result(model, test_it)
# Out:
# Test loss: 2.35
# Test Accuracy: 0.50
# Test Precision: 0.00
# Test True Positive Rate: 0.00

# %% [markdown]
# # 3. Summary

# %% [markdown]
# 30th epoch result:

# %%
from crack_utils import get_percentile_result

result_30 = get_percentile_result(histories, 30)
result_30.round(2)
# Out:
#            Bi_TH_Residual_1  Bi_TH_Residual_2  Bi_TH_Residual_2_dropout  \
# Loss                   0.69              0.69                      0.69
# Accuracy               0.50              0.50                      0.50
# Precision              0.00              0.50                      0.50
# TPR                    0.00              1.00                      1.00
#
#            Bi_TH_Residual_2_dropout_decay
# Loss                                 2.35
# Accuracy                             0.50
# Precision                            0.00
# TPR                                  0.00

# %% [markdown]
# 21-30 epochs (Average):

# %%
from crack_utils import get_avg_result

avg_result = get_avg_result(histories, start_epoch=21)
avg_result.round(2)
# Out:
#            Bi_TH_Residual_1  Bi_TH_Residual_2  Bi_TH_Residual_2_dropout  \
# Loss                   0.69              0.69                      0.69
# Accuracy               0.50              0.50                      0.50
# Precision              0.39              0.50                      0.06
# TPR                    0.78              1.00                      0.11
#
#            Bi_TH_Residual_2_dropout_decay
# Loss                                 2.59
# Accuracy                             0.50
# Precision                            0.22
# TPR                                  0.44

# %% [markdown]
# Compare each model:

# %%
from crack_utils import compare_all_result

compare_all_result(histories, filename="model_plot/Compare_Bi_TH_Residual.png", end=30, step=5)

# %% [markdown]
# Save epochs history:

# %%
from crack_utils import save_history

save_history(histories, folder="epochs_history")
