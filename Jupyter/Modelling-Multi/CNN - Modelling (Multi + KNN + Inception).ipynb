# %% [markdown]
# # CNN - Modelling (Multi + KNN + Inception)
#
# # 1. Construct `ImageDataGenerator` Instance

# %%
import tensorflow as tf
# %matplotlib inline

CLASS = "Mul"
PRE = "KNN"
TECH = "Inception"

print(tf.__version__)
# Out:
# 2.4.2

# %%
! nvidia-smi
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Sat Aug 21 05:22:56 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.142.00   Driver Version: 450.142.00   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   50C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# We center and standardize all images at per image level.
#
# Image flips, 180 degree image rotations and image brightness is suitable for data augmentation. However, shift and zoom are not appropriate because some crackes are located at the edge of some images. Zoom and shift may remove those crackes.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen_train = ImageDataGenerator(horizontal_flip=True,
                                    vertical_flip=True,
                                    samplewise_center=True,
                                    samplewise_std_normalization=True)

datagen_test = ImageDataGenerator(samplewise_center=True,
                                   samplewise_std_normalization=True)

# %% [markdown]
# Then, load the data from directory: to relieve the burden of memory usage, import the image as 150 $\times$ 150 squares.

# %%
SRC_MULTI = "/home/ubuntu/crack/KNN-Multi/"

from crack_utils import load_multi_dataset

x_train, x_test, y_train, y_test = load_multi_dataset(SRC_MULTI, (150, 150))

# %% [markdown]
# We can see that the classes are extremely imbalanced.

# %%
import numpy as np
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([1158,  716,  484,  100,   83]))

# %%
np.unique(y_test, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([385, 238, 161,  33,  27]))

# %% [markdown]
# Two common ways to alleviate this issue:
#
# * Over-sampling minority classes by image augmentation (e.g., flip)
#
# * Set class weight in training.
#
# However, we've found that such methods cannot leaed to a better validation accuracy and F1 score.
#
# We keep the code here:
#
# ```python
# # Over-sampling minority classes by image augmentation
# from crack_utils import augment_data
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# gen_temp = ImageDataGenerator()
# x_train, y_train = augment_data(x_train, y_train, gen_temp)
#
# # Set class weight in training.
# import numpy as np
# from sklearn.utils.class_weight import compute_class_weight
#
# class_weights = compute_class_weight('balanced', np.unique(np.argmax(y_train, axis=1)), np.argmax(y_train, axis=1))
# class_weights = dict(enumerate(class_weights))
# ```

# %% [markdown]
# Add to a data iterator:

# %%
from tensorflow.keras.utils import to_categorical

# convert integers to dummy variables (i.e. one hot encoded)
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

train_it = datagen_train.flow(x_train, y_train, batch_size=64, seed=100)
test_it = datagen_test.flow(x_test, y_test, batch_size=64, shuffle=False)

# %% [markdown]
# # 2. Inception Model
#
# ## 2.1 Baseline Model
#
# We consider VGG blocks in our baseline model.
#
# ### 2.2.2 One Block Inception Model

# %%
from crack_utils import naive_inception_module, classification_block, multiple_compile, feature_reduce_block
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input

def one_block_Inception():
    # define model input
    visible = Input(shape=(150, 150, 1))
    # add inception module
    layer = naive_inception_module(visible, 64, 128, 32)
    # add feature reduce block
    layer = feature_reduce_block(layer, 32, (2,2))
    # add classification block
    layer = classification_block(layer, 16, classes=5)
    # create model
    model = Model(inputs=visible, outputs=layer)
    return model

# create model instance
model = one_block_Inception()
multiple_compile(model, 0.001, 0.9)
model.summary()
# Out:
# Extension horovod.torch has not been built: /home/ubuntu/anaconda3/envs/tensorflow2_latest_p37/lib/python3.7/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-37m-x86_64-linux-gnu.so not found
# If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# Warning! MPI libs are missing, but python applications are still avaiable.
# [2021-08-21 05:23:06.043 ip-172-31-5-51:19409 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-08-21 05:23:06.065 ip-172-31-5-51:19409 INFO profiler_config_parser.py:102] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 150, 150, 64) 128         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 150, 150, 128 1280        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 150, 150, 32) 832         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 150, 150, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 150, 150, 225 0           conv2d[0][0]
#                                                                  conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 150, 150, 32) 7232        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 75, 75, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 180000)       0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           2880016     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 5)            85          dense[0][0]
# ==================================================================================================
# Total params: 2,889,573
# Trainable params: 2,889,573
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

# plot model architecture
model_name = "{}_{}_{}_1".format(CLASS, PRE, TECH)
plot_model(model, show_shapes=True, to_file='model_image/{}.png'.format(model_name))

# %%
# %%time

histories = dict()

histories[model_name] = model.fit(x=train_it, steps_per_epoch=len(train_it),
              validation_data=test_it, validation_steps=len(test_it), epochs=30, verbose=0).history
# Out:
# CPU times: user 2min 39s, sys: 8.97 s, total: 2min 48s
# Wall time: 3min 58s

# %%
from crack_utils import summarize_diagnostics_multi
                                           
summarize_diagnostics_multi(histories[model_name], "model_plot/{}.png".format(model_name))

# %%
from crack_utils import show_result_multi

results = dict()

results[model_name] = show_result_multi(model, test_it, y_test)
# Out:
# Test loss: 2.31
# Test accuracy: 0.46
# Test f1 micro: 0.46
# Test f1 macro: 0.30
# Test f1 weighted: 0.44

# %% [markdown]
# ### 2.1.2 Two Block Inception Model

# %%
def two_block_Inception():
    # define model input
    visible = Input(shape=(150, 150, 1))
    # add inception module
    layer = naive_inception_module(visible, 64, 128, 32)
    # add feature reduce block
    layer = feature_reduce_block(layer, 32, (2,2))
    # add inception module
    layer = naive_inception_module(layer, 96, 192, 64)
    # add feature reduce block
    layer = feature_reduce_block(layer, 32, (2,2))
    # add classification block
    layer = classification_block(layer, 16, classes=5)
    # create model
    model = Model(inputs=visible, outputs=layer)
    return model

# create model instance
model = two_block_Inception()
multiple_compile(model, 0.001, 0.9)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 150, 150, 64) 128         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 150, 150, 128 1280        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 150, 150, 32) 832         input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 150, 150, 1)  0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 150, 150, 225 0           conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 150, 150, 32) 7232        concatenate_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 75, 75, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 75, 75, 96)   3168        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 75, 75, 192)  55488       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 75, 75, 64)   51264       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 75, 75, 32)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 75, 75, 384)  0           conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 75, 75, 32)   12320       concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 38, 38, 32)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 46208)        0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           739344      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 5)            85          dense_2[0][0]
# ==================================================================================================
# Total params: 871,141
# Trainable params: 871,141
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# plot model architecture
model_name = "{}_{}_{}_2".format(CLASS, PRE, TECH)
plot_model(model, show_shapes=True, to_file='model_image/{}.png'.format(model_name))

# %%
# %%time

histories[model_name] = model.fit(train_it, steps_per_epoch=len(train_it),
              validation_data=test_it, validation_steps=len(test_it), epochs=30, verbose=0).history
# Out:
# CPU times: user 4min 10s, sys: 12.5 s, total: 4min 22s
# Wall time: 6min 7s

# %%
summarize_diagnostics_multi(histories[model_name], "model_plot/{}.png".format(model_name))

# %%
results[model_name] = show_result_multi(model, test_it, y_test)
# Out:
# Test loss: 1.45
# Test accuracy: 0.51
# Test f1 micro: 0.51
# Test f1 macro: 0.36
# Test f1 weighted: 0.48

# %% [markdown]
# ## 2.2 Model Improvements
#
# ### 2.2.1 Dropout Regularization

# %%
from tensorflow.keras.layers import Dropout

def two_block_Inception_dropout():
    # define model input
    visible = Input(shape=(150, 150, 1))
    # add inception module
    layer = naive_inception_module(visible, 64, 128, 32)
    # add feature reduce block
    layer = feature_reduce_block(layer, 32, (2,2))
    layer = Dropout(0.3)(layer)
    # add inception module
    layer = naive_inception_module(layer, 96, 192, 64)
    # add feature reduce block
    layer = feature_reduce_block(layer, 32, (2,2))
    layer = Dropout(0.4)(layer)
    # add classification block
    layer = classification_block(layer, 16, classes=5)
    # create model
    model = Model(inputs=visible, outputs=layer)
    return model

# create model instance
model = two_block_Inception_dropout()
multiple_compile(model, 0.001, 0.9)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 150, 150, 64) 128         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 150, 150, 128 1280        input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 150, 150, 32) 832         input_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 150, 150, 1)  0           input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 150, 150, 225 0           conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 150, 150, 32) 7232        concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 75, 75, 32)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 75, 75, 32)   0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 75, 75, 96)   3168        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 75, 75, 192)  55488       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 75, 75, 64)   51264       dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 75, 75, 32)   0           dropout[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 75, 75, 384)  0           conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 75, 75, 32)   12320       concatenate_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 38, 38, 32)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 38, 38, 32)   0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 46208)        0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           739344      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 5)            85          dense_4[0][0]
# ==================================================================================================
# Total params: 871,141
# Trainable params: 871,141
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# plot model architecture
model_name = "{}_{}_{}_2_dropout".format(CLASS, PRE, TECH)
plot_model(model, show_shapes=True, to_file='model_image/{}.png'.format(model_name))

# %%
# %%time

histories[model_name] = model.fit(train_it, steps_per_epoch=len(train_it),
              validation_data=test_it, validation_steps=len(test_it), epochs=30, verbose=0).history
# Out:
# CPU times: user 3min 59s, sys: 13.8 s, total: 4min 13s
# Wall time: 6min

# %%
summarize_diagnostics_multi(histories[model_name], "model_plot/{}.png".format(model_name))

# %%
results[model_name] = show_result_multi(model, test_it, y_test)
# Out:
# Test loss: 1.22
# Test accuracy: 0.43
# Test f1 micro: 0.43
# Test f1 macro: 0.34
# Test f1 weighted: 0.42

# %% [markdown]
# ### 2.2.1 Weight Decay + Dropout

# %%
from tensorflow.keras.regularizers import l2

def two_block_Inception_dropout_decay():
    # define model input
    visible = Input(shape=(150, 150, 1))
    # add inception module
    layer = naive_inception_module(visible, 64, 128, 32, decay=l2(0.01))
    # add feature reduce block
    layer = feature_reduce_block(layer, 32, (2,2))
    layer = Dropout(0.3)(layer)
    # add inception module
    layer = naive_inception_module(layer, 96, 192, 64, decay=l2(0.01))
    # add feature reduce block
    layer = feature_reduce_block(layer, 32, (2,2))
    layer = Dropout(0.4)(layer)
    # add classification block
    layer = classification_block(layer, 16, decay=l2(0.01), classes=5)
    # create model
    model = Model(inputs=visible, outputs=layer)
    return model

# create model instance
model = two_block_Inception_dropout_decay()
multiple_compile(model, 0.001, 0.9)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 150, 150, 64) 128         input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 150, 150, 128 1280        input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 150, 150, 32) 832         input_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 150, 150, 1)  0           input_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 150, 150, 225 0           conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 150, 150, 32) 7232        concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 75, 75, 32)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 75, 75, 32)   0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 75, 75, 96)   3168        dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 75, 75, 192)  55488       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 75, 75, 64)   51264       dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 75, 75, 32)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 75, 75, 384)  0           conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 75, 75, 32)   12320       concatenate_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 38, 38, 32)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 38, 38, 32)   0           max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 46208)        0           dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 16)           739344      flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 5)            85          dense_6[0][0]
# ==================================================================================================
# Total params: 871,141
# Trainable params: 871,141
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# plot model architecture
model_name = "{}_{}_{}_2_dropout_decay".format(CLASS, PRE, TECH)
plot_model(model, show_shapes=True, to_file='model_image/{}.png'.format(model_name))

# %%
# %%time

histories[model_name] = model.fit(train_it, steps_per_epoch=len(train_it),
              validation_data=test_it, validation_steps=len(test_it), epochs=30, verbose=0).history
# Out:
# CPU times: user 4min 2s, sys: 15.4 s, total: 4min 17s
# Wall time: 6min 1s

# %%
summarize_diagnostics_multi(histories[model_name], "model_plot/{}.png".format(model_name))

# %%
results[model_name] = show_result_multi(model, test_it, y_test)
# Out:
# Test loss: 2.39
# Test accuracy: 0.45
# Test f1 micro: 0.45
# Test f1 macro: 0.27
# Test f1 weighted: 0.40

# %% [markdown]
# # 3. Summary

# %% [markdown]
# Final result:

# %%
from crack_utils import get_final_result

get_final_result(results).round(2)
# Out:
#              Mul_KNN_Inception_1  Mul_KNN_Inception_2  \
# Loss                        2.31                 1.45
# Accuracy                    0.46                 0.51
# F1 Micro                    0.46                 0.51
# F1 Macro                    0.30                 0.36
# F1 Weighted                 0.44                 0.48
#
#              Mul_KNN_Inception_2_dropout  Mul_KNN_Inception_2_dropout_decay
# Loss                                1.22                               2.39
# Accuracy                            0.43                               0.45
# F1 Micro                            0.43                               0.45
# F1 Macro                            0.34                               0.27
# F1 Weighted                         0.42                               0.40

# %% [markdown]
# Compare each model:

# %%
from crack_utils import compare_all_result_multi

compare_all_result_multi(histories, filename="model_plot/Compare_{}_{}_{}.png".format(CLASS, PRE, TECH), end=30, step=5)

# %% [markdown]
# Save epochs history:

# %%
from crack_utils import save_history

save_history(histories, folder="epochs_history")
